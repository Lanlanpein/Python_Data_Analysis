# %%
import pandas as pd

# %%
pd.read_json("./练习/数据获取与读取/cell_phones_survey.json")
# Out:
#   questionType        asin    answerTime    unixTime  \
# 0       yes/no  1466736038   Mar 8, 2014  1394265600
# 1       yes/no  1466736038  Jan 29, 2015  1422518400
# 2       yes/no  1466736038  Nov 30, 2014  1417334400
# 3   open-ended  1466736038   Nov 3, 2014  1415001600
# 4       yes/no  1466736038   Oct 2, 2014  1412233200
# 5   open-ended  1466736038  Sep 11, 2014  1410418800
# 6       yes/no  1621911888  Dec 13, 2013  1386921600
#
#                                             question answerType  \
# 0                         Is there a SIM card in it?          Y
# 1  Is this phone new, with 1 year manufacture war...          ?
# 2  can in it be used abroad with a different carr...          Y
# 3                      What is the warranty on this?        NaN
# 4  Does this phone use the regular Sim card (the ...          ?
# 5  how much time you need to send me this product...        NaN
# 6                                    Is it unlocked?          Y
#
# ...

# %% [markdown]
# # 将JSON文件转换为Dataframe

# %%
pd.read_csv("./练习/数据获取与读取/fifa_players.csv")
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_38424\934485743.py:1: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("./练习/数据获取与读取/fifa_players.csv")
#         player_id                                        player_url  \
# 0          158023                /player/158023/lionel-messi/150002
# 1           20801  /player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2            9014                  /player/9014/arjen-robben/150002
# 3           41236           /player/41236/zlatan-ibrahimovic/150002
# 4          167495                /player/167495/manuel-neuer/150002
# ...           ...                                               ...
# 161578     269011                   /player/269011/ziye-zhao/230002
# 161579     269019                   /player/269019/junjie-wu/230002
# 161580     271093               /player/271093/kailin-barlow/230002
# 161581     271555               /player/271555/gideon-tetteh/230002
# ...

# %%
df1 = pd.read_csv("./练习/数据获取与读取/fifa_players.csv", index_col="player_id")
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_38424\4063414695.py:1: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("./练习/数据获取与读取/fifa_players.csv", index_col="player_id")

# %%
pd.set_option("display.max_columns", 150)
df1
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
# ...                                                     ...           ...
# 269011                      /player/269011/ziye-zhao/230002            23
# 269019                      /player/269019/junjie-wu/230002            23
# 271093                  /player/271093/kailin-barlow/230002            23
# 271555                  /player/271555/gideon-tetteh/230002            23
# 271608              /player/271608/aqeel-al-dhafeeri/230002            23
#
#            fifa_update fifa_update_date         short_name  \
# ...

# %%
df1.head(100)
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
# ...                                                     ...           ...
# 189362      /player/189362/givanildo-vieira-de-souza/150002            15
# 189505        /player/189505/pedro-rodriguez-ledesma/150002            15
# 193080          /player/193080/david-de-gea-quintana/150002            15
# 193082                  /player/193082/juan-cuadrado/150002            15
# 195864                     /player/195864/paul-pogba/150002            15
#
#            fifa_update fifa_update_date         short_name  \
# ...

# %%
df1.tail(100)
# Out:
#                                           player_url  fifa_version  \
# player_id
# 265463       /player/265463/danstan-fernandes/230002            23
# 265584         /player/265584/sharon-padattil/230002            23
# 265586     /player/265586/damaitphang-lyngdoh/230002            23
# 268918              /player/268918/yanpu-chen/230002            23
# 268968             /player/268968/yixuan-yang/230002            23
# ...                                              ...           ...
# 269011               /player/269011/ziye-zhao/230002            23
# 269019               /player/269019/junjie-wu/230002            23
# 271093           /player/271093/kailin-barlow/230002            23
# 271555           /player/271555/gideon-tetteh/230002            23
# 271608       /player/271608/aqeel-al-dhafeeri/230002            23
#
#            fifa_update fifa_update_date      short_name            long_name  \
# player_id
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161583 entries, 158023 to 271608
# Columns: 109 entries, player_url to player_face_url
# dtypes: float64(18), int64(44), object(47)
# memory usage: 135.6+ MB

# %%
df1.describe()
# Out:
#         fifa_version  fifa_update        overall      potential     value_eur  \
# count  161583.000000     161583.0  161583.000000  161583.000000  1.595300e+05
# mean       19.125514          2.0      65.699071      70.744008  2.326770e+06
# std         2.559318          0.0       7.040855       6.259121  6.005746e+06
# min        15.000000          2.0      40.000000      40.000000  1.000000e+03
# 25%        17.000000          2.0      61.000000      66.000000  3.250000e+05
# 50%        19.000000          2.0      66.000000      70.000000  7.250000e+05
# 75%        21.000000          2.0      70.000000      75.000000  1.800000e+06
# max        23.000000          2.0      94.000000      95.000000  1.940000e+08
#
#             wage_eur            age      height_cm      weight_kg  \
# count  159822.000000  161583.000000  161583.000000  161583.000000
# mean    10855.409768      25.123181     181.240205      75.235031
# std     21941.656285       4.670207       6.750148       7.000456
# ...
